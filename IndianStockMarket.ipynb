# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
daily = yf.download(tickers='EICHERMOT.NS',period = 'max',interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
daily
# Out:
#                Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-01     3.60     3.600000     3.600000     3.600000     1.173881
# 1996-01-02     3.60     3.640000     3.600000     3.610000     1.177142
# 1996-01-03     3.65     3.650000     3.650000     3.650000     1.190185
# 1996-01-04     3.60     3.650000     3.600000     3.650000     1.190185
# 1996-01-05     3.65     3.650000     3.540000     3.600000     1.173881
# ...             ...          ...          ...          ...          ...
# 2024-04-26  4591.00  4632.850098  4572.000000  4601.000000  4601.000000
# 2024-04-29  4589.00  4603.549805  4532.600098  4571.850098  4571.850098
# 2024-04-30  4578.00  4689.950195  4578.000000  4597.399902  4597.399902
# 2024-05-02  4598.00  4634.100098  4546.399902  4602.399902  4602.399902
# 2024-05-03  4623.00  4655.600098  4580.000000  4599.250000  4599.250000
#
#             Volume
# Date
# 1996-01-01   22000
# 1996-01-02   31000
# 1996-01-03   11000
# ...

# %%
daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7117 entries, 1996-01-01 to 2024-05-03
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       7117 non-null   float64
#  1   High       7117 non-null   float64
#  2   Low        7117 non-null   float64
#  3   Close      7117 non-null   float64
#  4   Adj Close  7117 non-null   float64
#  5   Volume     7117 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 389.2 KB

# %%
daily.shape
# Out:
# (7117, 6)

# %%
daily1 = yf.download(tickers='INFY.NS',period = 'max',interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
daily1
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-01     0.794921     0.796679     0.791015     0.796679     0.524797
# 1996-01-02     0.794921     0.798828     0.793457     0.793457     0.522674
# 1996-01-03     0.798828     0.798828     0.798828     0.798828     0.526212
# 1996-01-04     0.791015     0.794921     0.791015     0.793554     0.522738
# 1996-01-05     0.784179     0.784179     0.784179     0.784179     0.516563
# ...                 ...          ...          ...          ...          ...
# 2024-04-26  1439.699951  1445.400024  1427.000000  1430.250000  1430.250000
# 2024-04-29  1429.949951  1439.800049  1428.250000  1434.750000  1434.750000
# 2024-04-30  1434.699951  1436.550049  1417.550049  1420.550049  1420.550049
# 2024-05-02  1413.000000  1424.000000  1411.849976  1414.449951  1414.449951
# 2024-05-03  1422.099976  1424.800049  1403.199951  1416.300049  1416.300049
#
#               Volume
# Date
# ...

# %%
daily2 = yf.download(tickers='INFY.NS',period = 'max', interval = '1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
daily2
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-01     0.794921     0.796679     0.791015     0.796679     0.524797
# 1996-01-02     0.794921     0.798828     0.793457     0.793457     0.522674
# 1996-01-03     0.798828     0.798828     0.798828     0.798828     0.526212
# 1996-01-04     0.791015     0.794921     0.791015     0.793554     0.522738
# 1996-01-05     0.784179     0.784179     0.784179     0.784179     0.516563
# ...                 ...          ...          ...          ...          ...
# 2024-04-26  1439.699951  1445.400024  1427.000000  1430.250000  1430.250000
# 2024-04-29  1429.949951  1439.800049  1428.250000  1434.750000  1434.750000
# 2024-04-30  1434.699951  1436.550049  1417.550049  1420.550049  1420.550049
# 2024-05-02  1413.000000  1424.000000  1411.849976  1414.449951  1414.449951
# 2024-05-03  1422.099976  1424.800049  1403.199951  1416.300049  1416.300049
#
#               Volume
# Date
# ...

# %%
daily2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7120 entries, 1996-01-01 to 2024-05-03
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       7120 non-null   float64
#  1   High       7120 non-null   float64
#  2   Low        7120 non-null   float64
#  3   Close      7120 non-null   float64
#  4   Adj Close  7120 non-null   float64
#  5   Volume     7120 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 389.4 KB

# %%
daily2.shape
# Out:
# (7120, 6)

# %%
import pandas as pd
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
}
url = 'https://finance.yahoo.com/quote/INFY/history?period1=1556883068&period2=1714715931'
response = requests.get(url,headers = headers)

# %%
response.status_code
# Out:
# 200

# %%
#response.content

# %%
#response.text

# %%
infy_df = pd.read_html(response.text)

# %%
type(infy_df)
# Out:
# list

# %%
inffy_df = infy_df[0]
inffy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269 entries, 0 to 1268
# Data columns (total 7 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   Date                                                                                                1269 non-null   object
#  1   Open                                                                                                1269 non-null   object
#  2   High                                                                                                1269 non-null   object
#  3   Low                                                                                                 1269 non-null   object
# ...

# %%
inffy_df
# Out:
#               Date   Open   High    Low  \
# 0      May 2, 2024  16.85  16.91  16.63
# 1      May 1, 2024  16.72  16.89  16.68
# 2     Apr 30, 2024  16.93  16.95  16.71
# 3     Apr 29, 2024  16.95  17.09  16.93
# 4     Apr 26, 2024  17.11  17.13  16.88
# ...            ...    ...    ...    ...
# 1264   May 9, 2019  10.34  10.36  10.19
# 1265   May 8, 2019  10.42  10.43  10.26
# 1266   May 7, 2019  10.44  10.46  10.29
# 1267   May 6, 2019  10.31  10.52  10.31
# 1268   May 3, 2019  10.56  10.56  10.07
#
#      Close Close price adjusted for splits.  \
# 0                                     16.87
# 1                                     16.77
# 2                                     16.71
# 3                                     16.97
# 4                                     16.94
# ...                                     ...
# 1264                                  10.20
# 1265                                  10.39
# 1266                                  10.34
# ...

# %%
inffy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269 entries, 0 to 1268
# Data columns (total 7 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   Date                                                                                                1269 non-null   object
#  1   Open                                                                                                1269 non-null   object
#  2   High                                                                                                1269 non-null   object
#  3   Low                                                                                                 1269 non-null   object
# ...

# %%
inffy_df['Date'] = pd.to_datetime(inffy_df['Date'])

# %%
inffy_df.head()
# Out:
#         Date   Open   High    Low Close Close price adjusted for splits.  \
# 0 2024-05-02  16.85  16.91  16.63                                  16.87
# 1 2024-05-01  16.72  16.89  16.68                                  16.77
# 2 2024-04-30  16.93  16.95  16.71                                  16.71
# 3 2024-04-29  16.95  17.09  16.93                                  16.97
# 4 2024-04-26  17.11  17.13  16.88                                  16.94
#
#   Adj Close Adjusted close price adjusted for splits and dividend and/or capital gain distributions.  \
# 0                                              16.87
# 1                                              16.77
# 2                                              16.71
# 3                                              16.97
# 4                                              16.94
#
#      Volume
# 0   8716700
# 1   6966200
# 2  11349100
# 3   7426500
# 4   8845000

# %%
inffy_df['Open'] = pd.to_numeric(inffy_df['Open'],errors = 'coerce')

# %%
inffy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269 entries, 0 to 1268
# Data columns (total 7 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   Date                                                                                                1269 non-null   datetime64[ns]
#  1   Open                                                                                                1259 non-null   float64
#  2   High                                                                                                1269 non-null   object
#  3   Low                                                                                                 1269 non-null   object
# ...

# %%
# creating lists
l1 = ['Amar','Barsha','Carlos','tanmay','misbah']
l2 = ['Alpha','Bravo','Charlie','Tango','mike']
l3 = [23,25,22,27,29]
l4 = [69,54,73,70,74]
team = pd.DataFrame(list(zip(l1,l2,l3,l4)))
team
# Out:
#         0        1   2   3
# 0    Amar    Alpha  23  69
# 1  Barsha    Bravo  25  54
# 2  Carlos  Charlie  22  73
# 3  tanmay    Tango  27  70
# 4  misbah     mike  29  74

# %%
# Adding column name to the respective columns
team.columns = ['Name','Code','Age','Weight']

# %%
team
# Out:
#      Name     Code  Age  Weight
# 0    Amar    Alpha   23      69
# 1  Barsha    Bravo   25      54
# 2  Carlos  Charlie   22      73
# 3  tanmay    Tango   27      70
# 4  misbah     mike   29      74
